# %%
import math
import numpy as np
import os
from collections import defaultdict
import cv2
import matplotlib.pyplot as plt
import json
from PIL import Image
# %matplotlib inline

# %%
# !python tools/train.py -c en_PP-OCRv3_det_distill_train/config.yml
# Out:
# grep: warning: GREP_OPTIONS is deprecated; please use an alias or script
# [2023/06/21 17:02:00] ppocr INFO: Architecture :
# [2023/06/21 17:02:00] ppocr INFO:     Models :
# [2023/06/21 17:02:00] ppocr INFO:         Student :
# [2023/06/21 17:02:00] ppocr INFO:             Backbone :
# [2023/06/21 17:02:00] ppocr INFO:                 disable_se : True
# [2023/06/21 17:02:00] ppocr INFO:                 model_name : large
# [2023/06/21 17:02:00] ppocr INFO:                 name : MobileNetV3
# [2023/06/21 17:02:00] ppocr INFO:                 scale : 0.5
# [2023/06/21 17:02:00] ppocr INFO:             Head :
# [2023/06/21 17:02:00] ppocr INFO:                 k : 50
# [2023/06/21 17:02:00] ppocr INFO:                 name : DBHead
# [2023/06/21 17:02:00] ppocr INFO:             Neck :
# [2023/06/21 17:02:00] ppocr INFO:                 name : RSEFPN
# [2023/06/21 17:02:00] ppocr INFO:                 out_channels : 96
# ...

# %%
# !python tools/export_model.py -c en_PP-OCRv3_det_distill_train/config.yml -o Global.pretrained_model=./output/en_PP-OCR_v3_det2/best_accuracy Global.save_inference_dir=./inference2/det_db
# Out:
# grep: warning: GREP_OPTIONS is deprecated; please use an alias or script
# W0621 17:16:30.480356 19004 gpu_context.cc:278] Please NOTE: device: 0, GPU Compute Capability: 8.6, Driver API Version: 12.1, Runtime API Version: 11.2
# W0621 17:16:30.483621 19004 gpu_context.cc:306] device: 0, cuDNN Version: 8.1.
# [2023/06/21 17:16:32] ppocr INFO: load pretrain successful from ./output/en_PP-OCR_v3_det2/best_accuracy
# [2023/06/21 17:16:34] ppocr INFO: inference model is saved to ./inference2/det_db/Student/inference
# [2023/06/21 17:16:35] ppocr INFO: inference model is saved to ./inference2/det_db/Student2/inference
# [2023/06/21 17:16:36] ppocr INFO: inference model is saved to ./inference2/det_db/Teacher/inference
